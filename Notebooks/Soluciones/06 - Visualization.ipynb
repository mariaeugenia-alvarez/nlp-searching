# %% [markdown]
# # Visualización
#
# Cuando trabajamos con imágenes, datos numéricos, variables categóricas, series temporales... es sencillo imaginar posibles visualizaciones para representar las distribuciones de los datos, algunas estadísticas, etc.
#
# Cuando trabajamos con textos quizá no es tan intuitivo, ¿o si?
#
# A continuación se muestran algunos ejemplos de visualización de datos cuando trabajamos en NLP.

# %% [markdown]
# # Frecuencia de palabras

# %%
#!pip install -r requirements.txt
# !pip install unzip
# Out:
# Collecting unzip
#   Downloading unzip-1.0.0.tar.gz (704 bytes)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: unzip
#   Building wheel for unzip (setup.py) ... done
#   Created wheel for unzip: filename=unzip-1.0.0-py3-none-any.whl size=1281 sha256=04829797da36f5b8aa05bedd712f882ee3d6cf481ac7bf0da7a8c92f40c1144d
#   Stored in directory: /root/.cache/pip/wheels/fb/5b/81/0f3e1e533b52883f88ab978178c15627a4fce4c13f74911dce
# Successfully built unzip
# Installing collected packages: unzip
# Successfully installed unzip-1.0.0

# %%
# !unzip inaugural.zip
# Out:
# Archive:  inaugural.zip
#    creating: inaugural/
#   inflating: __MACOSX/._inaugural
#   inflating: inaugural/1957-Eisenhower.txt
#   inflating: __MACOSX/inaugural/._1957-Eisenhower.txt
#   inflating: inaugural/1881-Garfield.txt
#   inflating: __MACOSX/inaugural/._1881-Garfield.txt
#   inflating: inaugural/1905-Roosevelt.txt
#   inflating: __MACOSX/inaugural/._1905-Roosevelt.txt
#   inflating: inaugural/1985-Reagan.txt
#   inflating: __MACOSX/inaugural/._1985-Reagan.txt
#   inflating: inaugural/1913-Wilson.txt
#   inflating: __MACOSX/inaugural/._1913-Wilson.txt
#   inflating: inaugural/1793-Washington.txt
#   inflating: __MACOSX/inaugural/._1793-Washington.txt
#   inflating: inaugural/1885-Cleveland.txt
#   inflating: __MACOSX/inaugural/._1885-Cleveland.txt
#   inflating: inaugural/1789-Washington.txt
#   inflating: __MACOSX/inaugural/._1789-Washington.txt
#   inflating: inaugural/1845-Polk.txt
#   inflating: __MACOSX/inaugural/._1845-Polk.txt
#   inflating: inaugural/1925-Coolidge.txt
#   inflating: __MACOSX/inaugural/._1925-Coolidge.txt
#   inflating: inaugural/1837-VanBuren.txt
#   inflating: __MACOSX/inaugural/._1837-VanBuren.txt
#   inflating: inaugural/1941-Roosevelt.txt
#   inflating: __MACOSX/inaugural/._1941-Roosevelt.txt
#   inflating: inaugural/2001-Bush.txt
#   inflating: __MACOSX/inaugural/._2001-Bush.txt
#   inflating: inaugural/1961-Kennedy.txt
#   inflating: __MACOSX/inaugural/._1961-Kennedy.txt
#   inflating: inaugural/1909-Taft.txt
#   inflating: __MACOSX/inaugural/._1909-Taft.txt
#   inflating: inaugural/1945-Roosevelt.txt
#   inflating: __MACOSX/inaugural/._1945-Roosevelt.txt
#   inflating: inaugural/1817-Monroe.txt
#   inflating: __MACOSX/inaugural/._1817-Monroe.txt
#   inflating: inaugural/1949-Truman.txt
#   inflating: __MACOSX/inaugural/._1949-Truman.txt
#   inflating: inaugural/1953-Eisenhower.txt
#   inflating: __MACOSX/inaugural/._1953-Eisenhower.txt
#   inflating: inaugural/1841-Harrison.txt
#   inflating: __MACOSX/inaugural/._1841-Harrison.txt
#   inflating: inaugural/1889-Harrison.txt
#   inflating: __MACOSX/inaugural/._1889-Harrison.txt
#   inflating: inaugural/1857-Buchanan.txt
#   inflating: __MACOSX/inaugural/._1857-Buchanan.txt
#   inflating: inaugural/2009-Obama.txt
#   inflating: __MACOSX/inaugural/._2009-Obama.txt
#   inflating: inaugural/1877-Hayes.txt
#   inflating: __MACOSX/inaugural/._1877-Hayes.txt
#   inflating: inaugural/1861-Lincoln.txt
#   inflating: __MACOSX/inaugural/._1861-Lincoln.txt
#   inflating: inaugural/1973-Nixon.txt
#   inflating: __MACOSX/inaugural/._1973-Nixon.txt
#   inflating: inaugural/1977-Carter.txt
#   inflating: __MACOSX/inaugural/._1977-Carter.txt
#   inflating: inaugural/README
#   inflating: __MACOSX/inaugural/._README
#   inflating: inaugural/1993-Clinton.txt
#   inflating: __MACOSX/inaugural/._1993-Clinton.txt
#   inflating: inaugural/1869-Grant.txt
#   inflating: __MACOSX/inaugural/._1869-Grant.txt
#   inflating: inaugural/1981-Reagan.txt
#   inflating: __MACOSX/inaugural/._1981-Reagan.txt
#   inflating: inaugural/1937-Roosevelt.txt
#   inflating: __MACOSX/inaugural/._1937-Roosevelt.txt
#   inflating: inaugural/1917-Wilson.txt
#   inflating: __MACOSX/inaugural/._1917-Wilson.txt
#   inflating: inaugural/1849-Taylor.txt
#   inflating: __MACOSX/inaugural/._1849-Taylor.txt
#   inflating: inaugural/1933-Roosevelt.txt
#   inflating: __MACOSX/inaugural/._1933-Roosevelt.txt
#   inflating: inaugural/1809-Madison.txt
#   inflating: __MACOSX/inaugural/._1809-Madison.txt
#   inflating: inaugural/2005-Bush.txt
#   inflating: __MACOSX/inaugural/._2005-Bush.txt
#   inflating: inaugural/1873-Grant.txt
#   inflating: __MACOSX/inaugural/._1873-Grant.txt
#   inflating: inaugural/1921-Harding.txt
#   inflating: __MACOSX/inaugural/._1921-Harding.txt
#   inflating: inaugural/1829-Jackson.txt
#   inflating: __MACOSX/inaugural/._1829-Jackson.txt
#   inflating: inaugural/1969-Nixon.txt
#   inflating: __MACOSX/inaugural/._1969-Nixon.txt
#   inflating: inaugural/1805-Jefferson.txt
#   inflating: __MACOSX/inaugural/._1805-Jefferson.txt
#   inflating: inaugural/1801-Jefferson.txt
#   inflating: __MACOSX/inaugural/._1801-Jefferson.txt
#   inflating: inaugural/1901-McKinley.txt
#   inflating: __MACOSX/inaugural/._1901-McKinley.txt
#   inflating: inaugural/1853-Pierce.txt
#   inflating: __MACOSX/inaugural/._1853-Pierce.txt
#   inflating: inaugural/1813-Madison.txt
#   inflating: __MACOSX/inaugural/._1813-Madison.txt
#   inflating: inaugural/1929-Hoover.txt
#   inflating: __MACOSX/inaugural/._1929-Hoover.txt
#   inflating: inaugural/1893-Cleveland.txt
#   inflating: __MACOSX/inaugural/._1893-Cleveland.txt
#   inflating: inaugural/1989-Bush.txt
#   inflating: __MACOSX/inaugural/._1989-Bush.txt
#   inflating: inaugural/1897-McKinley.txt
#   inflating: __MACOSX/inaugural/._1897-McKinley.txt
#   inflating: inaugural/1797-Adams.txt
#   inflating: __MACOSX/inaugural/._1797-Adams.txt
#   inflating: inaugural/1833-Jackson.txt
#   inflating: __MACOSX/inaugural/._1833-Jackson.txt
#   inflating: inaugural/1965-Johnson.txt
#   inflating: __MACOSX/inaugural/._1965-Johnson.txt
#   inflating: inaugural/1997-Clinton.txt
#   inflating: __MACOSX/inaugural/._1997-Clinton.txt
#   inflating: inaugural/1821-Monroe.txt
#   inflating: __MACOSX/inaugural/._1821-Monroe.txt
#   inflating: inaugural/1825-Adams.txt
#   inflating: __MACOSX/inaugural/._1825-Adams.txt
#   inflating: inaugural/1865-Lincoln.txt
#   inflating: __MACOSX/inaugural/._1865-Lincoln.txt

# %%
from collections import Counter
import matplotlib.pyplot as plt

# %%
# Prefacio del NLTK book
text = 'This is a book about Natural Language Processing. By "natural language" we mean a language that is used for everyday communication by humans; languages like English, Hindi or Portuguese. In contrast to artificial languages such as programming languages and mathematical notations, natural languages have evolved as they pass from generation to generation, and are hard to pin down with explicit rules. We will take Natural Language Processing — or NLP for short — in a wide sense to cover any kind of computer manipulation of natural language. At one extreme, it could be as simple as counting word frequencies to compare different writing styles. At the other extreme, NLP involves "understanding" complete human utterances, at least to the extent of being able to give useful responses to them. Technologies based on NLP are becoming increasingly widespread. For example, phones and handheld computers support predictive text and handwriting recognition; web search engines give access to information locked up in unstructured text; machine translation allows us to retrieve texts written in Chinese and read them in Spanish; text analysis enables us to detect sentiment in tweets and blogs. By providing more natural human-machine interfaces, and more sophisticated access to stored information, language processing has come to play a central role in the multilingual information society. This book provides a highly accessible introduction to the field of NLP. It can be used for individual study or as the textbook for a course on natural language processing or computational linguistics, or as a supplement to courses in artificial intelligence, text mining, or corpus linguistics. The book is intensely practical, containing hundreds of fully-worked examples and graded exercises. The book is based on the Python programming language together with an open source library called the Natural Language Toolkit (NLTK). NLTK includes extensive software, data, and documentation, all freely downloadable from http://nltk.org/. Distributions are provided for Windows, Macintosh and Unix platforms. We strongly encourage you to download Python and NLTK, and try out the examples and exercises along the way.'

# %%
words_nltk = text.lower().split()

# %%
words_nltk[:10]
# Out:
# ['this',
#  'is',
#  'a',
#  'book',
#  'about',
#  'natural',
#  'language',
#  'processing.',
#  'by',
#  '"natural']

# %%
wf = Counter(words_nltk)

# %%
wf_most_common = wf.most_common(10)

# %%
wf_most_common
# Out:
# [('to', 16),
#  ('and', 13),
#  ('the', 11),
#  ('in', 8),
#  ('a', 7),
#  ('natural', 7),
#  ('language', 7),
#  ('for', 6),
#  ('or', 6),
#  ('as', 6)]

# %%
words = [w[0] for w in wf_most_common]
freqs = [w[1] for w in wf_most_common]

# %%
freqs, words = zip(*sorted(zip(freqs, words)))

# %%
plt.barh(words, freqs)
plt.show()

# %% [markdown]
# # ... o de n-grams

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.1)

# %%
# from sklearn.feature_extraction.text import CountVectorizer
from nltk import ngrams
from nltk.probability import FreqDist

# %%
bigrams_ = list(ngrams(words_nltk, 2))
trigrams_ = list(ngrams(words_nltk, 3))

# %%
bigrams_[:10]
# Out:
# [('this', 'is'),
#  ('is', 'a'),
#  ('a', 'book'),
#  ('book', 'about'),
#  ('about', 'natural'),
#  ('natural', 'language'),
#  ('language', 'processing.'),
#  ('processing.', 'by'),
#  ('by', '"natural'),
#  ('"natural', 'language"')]

# %%
trigrams_[:10]
# Out:
# [('this', 'is', 'a'),
#  ('is', 'a', 'book'),
#  ('a', 'book', 'about'),
#  ('book', 'about', 'natural'),
#  ('about', 'natural', 'language'),
#  ('natural', 'language', 'processing.'),
#  ('language', 'processing.', 'by'),
#  ('processing.', 'by', '"natural'),
#  ('by', '"natural', 'language"'),
#  ('"natural', 'language"', 'we')]

# %%
bg_freq = FreqDist(bigrams_)
tg_freq = FreqDist(trigrams_)

# %%
bg_freq.most_common(10)
# Out:
# [(('natural', 'language'), 4),
#  (('language', 'processing'), 3),
#  (('used', 'for'), 2),
#  (('to', 'the'), 2),
#  (('based', 'on'), 2),
#  (('access', 'to'), 2),
#  (('us', 'to'), 2),
#  (('or', 'as'), 2),
#  (('the', 'book'), 2),
#  (('book', 'is'), 2)]

# %%
tg_freq.most_common(10)
# Out:
# [(('natural', 'language', 'processing'), 2),
#  (('the', 'book', 'is'), 2),
#  (('this', 'is', 'a'), 1),
#  (('is', 'a', 'book'), 1),
#  (('a', 'book', 'about'), 1),
#  (('book', 'about', 'natural'), 1),
#  (('about', 'natural', 'language'), 1),
#  (('natural', 'language', 'processing.'), 1),
#  (('language', 'processing.', 'by'), 1),
#  (('processing.', 'by', '"natural'), 1)]

# %%
bg_freq_most_common = bg_freq.most_common(10)
bgs_ = [str(bg[0]) for bg in bg_freq_most_common]
bgs_f_ = [bg[1] for bg in bg_freq_most_common]

tg_freq_most_common = tg_freq.most_common(10)
tgs_ = [str(tg[0]) for tg in tg_freq_most_common]
tgs_f_ = [tg[1] for tg in tg_freq_most_common]

# %%
bgs_f_, bgs_ = zip(*sorted(zip(bgs_f_, bgs_)))
tgs_f_, tgs_ = zip(*sorted(zip(tgs_f_, tgs_)))

# %%
plt.barh(bgs_, bgs_f_)
plt.title('Bigram frequencies')
plt.show()

# %%
plt.barh(tgs_, tgs_f_)
plt.title('Trigram frequencies')
plt.show()

# %%
# !pip install stop-words


from stop_words import get_stop_words

sw = get_stop_words (language = 'en')

new_text = [word for word in text.lower().split() if word in sw ]
print(new_text)
# Out:
# Collecting stop-words
#   Downloading stop_words-2025.11.4-py3-none-any.whl.metadata (14 kB)
# Downloading stop_words-2025.11.4-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: stop-words
# Successfully installed stop-words-2025.11.4
# ['this', 'is', 'a', 'about', 'by', 'we', 'mean', 'a', 'that', 'is', 'used', 'for', 'by', 'like', 'or', 'in', 'to', 'such', 'as', 'and', 'have', 'as', 'they', 'from', 'to', 'and', 'are', 'to', 'down', 'with', 'we', 'will', 'take', 'or', 'for', 'in', 'a', 'to', 'any', 'kind', 'of', 'computer', 'of', 'at', 'one', 'it', 'could', 'be', 'as', 'as', 'to', 'different', 'at', 'the', 'other', 'at', 'least', 'to', 'the', 'of', 'being', 'able', 'to', 'give', 'useful', 'to', 'on', 'are', 'becoming', 'for', 'and', 'text', 'and', 'web', 'give', 'to', 'information', 'up', 'in', 'allows', 'us', 'to', 'in', 'and', 'them', 'in', 'text', 'us', 'to', 'in', 'and', 'by', 'more', 'and', 'more', 'to', 'has', 'come', 'to', 'a', 'in', 'the', 'information', 'this', 'provides', 'a', 'to', 'the', 'of', 'it', 'can', 'be', 'used', 'for', 'or', 'as', 'the', 'for', 'a', 'course', 'on', 'or', 'or', 'as', 'a', 'to', 'in', 'text', 'or', 'the', 'is', 'containing', 'of', 'and', 'the', 'is', 'on', 'the', 'together', 'with', 'an', 'open', 'the', 'and', 'all', 'from', 'are', 'provided', 'for', 'and', 'we', 'strongly', 'you', 'to', 'and', 'and', 'try', 'out', 'the', 'and', 'along', 'the']

# %%
new_bigrams = list (ngrams(new_text, 2))
new_bg_freq = FreqDist(new_bigrams)
new_bg_freq.most_common(10)
# Out:
# [(('a', 'to'), 3),
#  (('to', 'in'), 3),
#  (('used', 'for'), 2),
#  (('to', 'and'), 2),
#  (('to', 'the'), 2),
#  (('the', 'of'), 2),
#  (('for', 'and'), 2),
#  (('us', 'to'), 2),
#  (('in', 'and'), 2),
#  (('in', 'text'), 2)]

# %% [markdown]
# # Word cloud

# %% [markdown]
# # Nueva sección

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
print(len(text))
# Out:
# 2206

# %%
print(text[:500])
# Out:
# This is a book about Natural Language Processing. By "natural language" we mean a language that is used for everyday communication by humans; languages like English, Hindi or Portuguese. In contrast to artificial languages such as programming languages and mathematical notations, natural languages have evolved as they pass from generation to generation, and are hard to pin down with explicit rules. We will take Natural Language Processing — or NLP for short — in a wide sense to cover any kind of

# %%
def plot_word_cloud(text):
    wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(' '.join(text))
    plt.figure(figsize=(12,6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
words_list = text.lower().strip().split()
plot_word_cloud(words_list)

# %% [markdown]
# # Dispersión léxica

# %%
import os
import glob
import matplotlib.pyplot as plt
from nltk.draw.dispersion import dispersion_plot

# %%
inaugural_folder = './inaugural'
inaugural_paths = [os.path.join(inaugural_folder, file) for file in sorted(os.listdir(inaugural_folder)) if '.txt' in file]

# %%
inaugural_paths
# Out:
# ['./inaugural/1789-Washington.txt',
#  './inaugural/1793-Washington.txt',
#  './inaugural/1797-Adams.txt',
#  './inaugural/1801-Jefferson.txt',
#  './inaugural/1805-Jefferson.txt',
#  './inaugural/1809-Madison.txt',
#  './inaugural/1813-Madison.txt',
#  './inaugural/1817-Monroe.txt',
#  './inaugural/1821-Monroe.txt',
#  './inaugural/1825-Adams.txt',
#  './inaugural/1829-Jackson.txt',
#  './inaugural/1833-Jackson.txt',
#  './inaugural/1837-VanBuren.txt',
#  './inaugural/1841-Harrison.txt',
#  './inaugural/1845-Polk.txt',
#  './inaugural/1849-Taylor.txt',
#  './inaugural/1853-Pierce.txt',
#  './inaugural/1857-Buchanan.txt',
#  './inaugural/1861-Lincoln.txt',
#  './inaugural/1865-Lincoln.txt',
#  './inaugural/1869-Grant.txt',
#  './inaugural/1873-Grant.txt',
#  './inaugural/1877-Hayes.txt',
#  './inaugural/1881-Garfield.txt',
#  './inaugural/1885-Cleveland.txt',
#  './inaugural/1889-Harrison.txt',
#  './inaugural/1893-Cleveland.txt',
#  './inaugural/1897-McKinley.txt',
#  './inaugural/1901-McKinley.txt',
#  './inaugural/1905-Roosevelt.txt',
#  './inaugural/1909-Taft.txt',
#  './inaugural/1913-Wilson.txt',
#  './inaugural/1917-Wilson.txt',
#  './inaugural/1921-Harding.txt',
#  './inaugural/1925-Coolidge.txt',
#  './inaugural/1929-Hoover.txt',
#  './inaugural/1933-Roosevelt.txt',
#  './inaugural/1937-Roosevelt.txt',
#  './inaugural/1941-Roosevelt.txt',
#  './inaugural/1945-Roosevelt.txt',
#  './inaugural/1949-Truman.txt',
#  './inaugural/1953-Eisenhower.txt',
#  './inaugural/1957-Eisenhower.txt',
#  './inaugural/1961-Kennedy.txt',
#  './inaugural/1965-Johnson.txt',
#  './inaugural/1969-Nixon.txt',
#  './inaugural/1973-Nixon.txt',
#  './inaugural/1977-Carter.txt',
#  './inaugural/1981-Reagan.txt',
#  './inaugural/1985-Reagan.txt',
#  './inaugural/1989-Bush.txt',
#  './inaugural/1993-Clinton.txt',
#  './inaugural/1997-Clinton.txt',
#  './inaugural/2001-Bush.txt',
#  './inaugural/2005-Bush.txt',
#  './inaugural/2009-Obama.txt']

# %%
texts = list()
for file_path in inaugural_paths:
    with open(file_path, mode='r', encoding='latin-1') as f:
        texts.append(f.read())

# %%
print(texts[0][:1000])
# Out:
# Fellow-Citizens of the Senate and of the House of Representatives:
#
# Among the vicissitudes incident to life no event could have filled me with greater anxieties than that of which the notification was transmitted by your order, and received on the 14th day of the present month. On the one hand, I was summoned by my Country, whose voice I can never hear but with veneration and love, from a retreat which I had chosen with the fondest predilection, and, in my flattering hopes, with an immutable decision, as the asylum of my declining years -- a retreat which was rendered every day more necessary as well as more dear to me by the addition of habit to inclination, and of frequent interruptions in my health to the gradual waste committed on it by time. On the other hand, the magnitude and difficulty of the trust to which the voice of my country called me, being sufficient to awaken in the wisest and most experienced of her citizens a distrustful scrutiny into his qualifications, could not bu

# %%
words = [word.lower() for text in texts for word in text.split()]

# %%
target_words = [
    'democracy',
    'citizens',
    'freedom',
    'duties',
    'america'
]

# %%
plt.figure(figsize=(12, 9))
plt.style.use('default')
dispersion_plot(words, target_words, ignore_case=True)
plt.show()

# %% [markdown]
# ## Ejemplo: Google Ngram Viewer
#
# Buscador online que permite representar en un gráfico la frecuencia anual de distintos ngrams detectados en los corpus que tiene Google disponibles para multitud de idiomas.
#
# <img src=https://images2.minutemediacdn.com/image/upload/c_fit,f_auto,fl_lossy,q_auto,w_728/v1555921104/shape/mentalfloss/screen_shot_2014-11-12_at_1.43.16_pm.png>
#
# Link: https://books.google.com/ngrams#
#
# Alguna curiosidad:
# - Artículo: _Experiments in Ngram Art_, [link](https://www.mentalfloss.com/article/60033/experiments-ngram-art)
# - TED Talk: _What we learned from 5 million books_, [link](https://www.ted.com/talks/jean_baptiste_michel_erez_lieberman_aiden_what_we_learned_from_5_million_books/up-next?language=en)

# %% [markdown]
# # Ley de Zipf

# %% [markdown]
# Formulada en la década de 1940 por el lingüista George Kingsley Zipf, establece que, dada una lengua, la frecuencia de aparición de las distintas palabras de su vocabulario sigue una distribución que puede aproximarse por:
#
# <img src=https://wikimedia.org/api/rest_v1/media/math/render/svg/9fa76f350fe93da686890acfb9b8e3b1151b85bc>
#
# Gráfico log-log con el ranking y la frecuencia de las 10 millones de palabras más frecuentes (medido con artículos de Wikipedia) para distintos idiomas:
# <img src=https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/Zipf_30wiki_es_labels.png/1200px-Zipf_30wiki_es_labels.png>

# %%
import matplotlib.pyplot as plt
from nltk.probability import FreqDist

# %%
fd = FreqDist(words)

# %%
fd
# Out:
# FreqDist({'the': 9889, 'of': 6981, 'and': 5067, 'to': 4403, 'in': 2731, 'a': 2184, 'our': 2054, 'that': 1696, 'we': 1611, 'be': 1435, ...})

# %%
fd = {k: v for k, v in sorted(fd.items(), key=lambda item: item[1], reverse=True)}

# %%
ranks = list()
freqs = list()

for rank, word in enumerate(fd):
    ranks.append(rank+1)
    freqs.append(fd[word])

# %%
plt.loglog(ranks, freqs)
plt.xlabel('Rank')
plt.ylabel('Freq')
plt.title('Log-Log rank-freq chart')
plt.show()
